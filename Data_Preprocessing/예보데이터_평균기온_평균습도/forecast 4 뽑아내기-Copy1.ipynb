# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\82102\\OneDrive\\바탕화~1-LAPTOP-GKOMRU8U-8903771\\예보데이터\\2015\\광주\\운암1동_3시간기온_201501_201512.csv")

# %%
df.shape
# Out:
# (52530, 4)

# %%
df.columns
# Out:
# Index([' format: day', 'hour', 'forecast',
#        'value  location:59_75 Start : 20150101 '],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        format: day    hour  forecast  value  location:59_75 Start : 20150101
# 0                1   200.0       4.0                                     -1.0
# 1                1   200.0       7.0                                     -1.0
# 2                1   200.0      10.0                                     -2.0
# 3                1   200.0      13.0                                     -3.0
# 4                1   200.0      16.0                                     -2.0
# ...            ...     ...       ...                                      ...
# 52525           31  2300.0      52.0                                     10.0
# 52526           31  2300.0      55.0                                     12.0
# 52527           31  2300.0      58.0                                      9.0
# 52528           31  2300.0      61.0                                      7.0
# 52529           31  2300.0      64.0                                      5.0
#
# [52530 rows x 4 columns]>

# %%
df.query('forecast == 4')
# Out:
#        format: day    hour  forecast  value  location:59_75 Start : 20150101
# 0                1   200.0       4.0                                     -1.0
# 20               1   500.0       4.0                                     -1.0
# 39               1   800.0       4.0                                     -4.0
# 57               1  1100.0       4.0                                     -4.0
# 74               1  1400.0       4.0                                     -4.0
# ...            ...     ...       ...                                      ...
# 52439           31  1100.0       4.0                                      1.0
# 52456           31  1400.0       4.0                                      0.0
# 52472           31  1700.0       4.0                                     -1.0
# 52487           31  2000.0       4.0                                      1.0
# 52509           31  2300.0       4.0                                      5.0
#
# [2839 rows x 4 columns]

# %%
df1 = df.query('forecast == 4')

# %%
df1.head(10)
# Out:
#      format: day    hour  forecast  value  location:59_75 Start : 20150101
# 0              1   200.0       4.0                                     -1.0
# 20             1   500.0       4.0                                     -1.0
# 39             1   800.0       4.0                                     -4.0
# 57             1  1100.0       4.0                                     -4.0
# 74             1  1400.0       4.0                                     -4.0
# 90             1  1700.0       4.0                                     -3.0
# 105            1  2000.0       4.0                                     -1.0
# 127            1  2300.0       4.0                                      1.0
# 148            2   200.0       4.0                                      3.0
# 168            2   500.0       4.0                                      0.0

# %%
df1 = df1.rename(columns = {' format: day': 'day'})

# %%
df1
# Out:
#        day    hour  forecast  value  location:59_75 Start : 20150101
# 0        1   200.0       4.0                                     -1.0
# 20       1   500.0       4.0                                     -1.0
# 39       1   800.0       4.0                                     -4.0
# 57       1  1100.0       4.0                                     -4.0
# 74       1  1400.0       4.0                                     -4.0
# ...    ...     ...       ...                                      ...
# 52439   31  1100.0       4.0                                      1.0
# 52456   31  1400.0       4.0                                      0.0
# 52472   31  1700.0       4.0                                     -1.0
# 52487   31  2000.0       4.0                                      1.0
# 52509   31  2300.0       4.0                                      5.0
#
# [2839 rows x 4 columns]

# %%
df1.columns
# Out:
# Index(['day', 'hour', 'forecast', 'value  location:59_75 Start : 20150101 '], dtype='object')

# %%
df1 = df1.rename(columns = {'value  location:65_139 Start : 20120101 ': 'value'})

# %%
df1
# Out:
#        day    hour  forecast  value  location:59_75 Start : 20150101
# 0        1   200.0       4.0                                     -1.0
# 20       1   500.0       4.0                                     -1.0
# 39       1   800.0       4.0                                     -4.0
# 57       1  1100.0       4.0                                     -4.0
# 74       1  1400.0       4.0                                     -4.0
# ...    ...     ...       ...                                      ...
# 52439   31  1100.0       4.0                                      1.0
# 52456   31  1400.0       4.0                                      0.0
# 52472   31  1700.0       4.0                                     -1.0
# 52487   31  2000.0       4.0                                      1.0
# 52509   31  2300.0       4.0                                      5.0
#
# [2839 rows x 4 columns]

# %%
df1 = df1.rename(columns = {'format..day': 'day'})

# %%
df1.to_csv('평기_미완.csv')
